# %%
import pandas as pd

# %%
data = pd.DataFrame({
    "text": [
        "I love this movie",
        "This movie is terrible",
        "Python is interesting",
        "Python is difficult"
    ],
    "label": [
        "positive",
        "negative",
        "positive",
        "negative"
    ]
})

# %%
data.head()
# Out:
#                      text     label
# 0       I love this movie  positive
# 1  This movie is terrible  negative
# 2   Python is interesting  positive
# 3     Python is difficult  negative

# %%
data['label']
# Out:
# 0    positive
# 1    negative
# 2    positive
# 3    negative
# Name: label, dtype: object

# %%
data['label'].value_counts()
# Out:
# label
# positive    2
# negative    2
# Name: count, dtype: int64
